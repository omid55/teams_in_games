# %%
import download_data
download_data.run(key_file_name='MyKey6.key', myrange=range(20012512, 22000000)) #=range(607310, 800000))  # 300000 to 500000 has not completely checked but mostly has nothing in it
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20014401.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20015934.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20018305.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20020672.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20022691.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid20025680.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# ...
