# %%
import download_data
download_data.run(key_file_name='MyKey3.key', myrange=range(30012363, 40000000)) #=range(110347, 300000)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30014331.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30015854.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30018589.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30023348.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30027038.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid30031608.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# ...
