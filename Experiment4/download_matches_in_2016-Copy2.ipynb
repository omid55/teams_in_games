# %%
import download_data
download_data.run(key_file_name='MyKey4.key', myrange=range(72900, 100000))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid74770.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid76528.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid78821.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid83625.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid87144.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10000 samples are saving in file MATCHES_till_sid91402.pkl ...
# Done.
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# ...
