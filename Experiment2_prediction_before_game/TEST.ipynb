# %%
# %matplotlib inline
import classification_pipeline as pi

# %%
pi.run('Stat2016_for_Classification2016_Dataset.csv')
# Out:
# Data size:  (1198, 17)
#                                 classifier  test acc  train acc
# 0   Stochastic Gradient Descent Classifier     89.06      90.24
# 1                                      KNN     88.14      91.52
# 2                            Decision Tree     90.39      95.69
# 3                              Naive Bayes     87.47      88.22
# 4                          Dummy (Uniform)     50.16      50.35
# 5                                 AdaBoost     91.23      95.96
# 6          Quadratic Discriminant Analysis     90.31      92.13
# 7                            Random Forest     92.82     100.00
# 8             Linear Discriminant Analysis     92.65      93.27
# 9                               Linear SVM     92.73      93.81
# 10                     Logistic Regression     92.57      93.78
# 11                     SVM with RBF kernel     91.81      95.19
# Computing embedding
# Done.
# average : 0.43s
# complete : 0.43s

# %%
pi.run('STAT2015.csv')
# Out:
# Data size:  (3245, 17)
#                                 classifier  test acc  train acc
# 0   Stochastic Gradient Descent Classifier     50.27      50.20
# 1                                      KNN     52.31      65.08
# 2                            Decision Tree     52.97      59.33
# 3                              Naive Bayes     51.79      52.50
# 4                          Dummy (Uniform)     49.98      49.85
# 5                                 AdaBoost     51.72      62.00
# 6          Quadratic Discriminant Analysis     51.79      53.98
# 7                            Random Forest     51.29     100.00
# 8             Linear Discriminant Analysis     51.29      54.06
# 9                               Linear SVM     51.35      53.99
# 10                     Logistic Regression     51.41      54.05
# 11                     SVM with RBF kernel     51.88      65.22
# Computing embedding
# Done.
# average : 9.10s
# complete : 8.94s

# %%
pi.run('Classification2016_Dataset.csv')
# Out:
# Data size:  (4215, 17)
#                                 classifier  test acc  train acc
# 0   Stochastic Gradient Descent Classifier     49.66      50.58
# 1                                      KNN     49.51      63.76
# 2                            Decision Tree     52.31      56.70
# 3                              Naive Bayes     49.70      52.07
# 4                          Dummy (Uniform)     51.29      50.14
# 5                                 AdaBoost     51.63      58.47
# 6          Quadratic Discriminant Analysis     50.06      52.23
# 7                            Random Forest     48.45     100.00
# 8             Linear Discriminant Analysis     52.22      53.78
# 9                               Linear SVM     52.12      53.78
# 10                     Logistic Regression     51.98      53.83
# 11                     SVM with RBF kernel     49.20      59.30
# Computing embedding
# Done.
# average : 21.25s
# complete : 19.26s

# %%
import warnings
warnings.filterwarnings('ignore')
pi.run('Classification2016_Dataset.csv')
# Out:
# Data size:  (5002, 39)
#                                 classifier  test acc  train acc
# 0   Stochastic Gradient Descent Classifier     49.38      50.60
# 1                                      KNN     50.30      63.39
# 2                            Decision Tree     50.74      56.64
# 3                              Naive Bayes     50.10      50.34
# 4                          Dummy (Uniform)     50.82      50.38
# 5                                 AdaBoost     51.56      58.56
# 6          Quadratic Discriminant Analysis     50.20      52.36
# 7                            Random Forest     50.14     100.00
# 8             Linear Discriminant Analysis     51.20      53.09
# 9                               Linear SVM     51.44      52.96
# 10                     Logistic Regression     51.08      53.04
# 11                     SVM with RBF kernel     50.54      57.93
# Computing embedding
# Done.
# average : 33.46s
# complete : 32.30s
